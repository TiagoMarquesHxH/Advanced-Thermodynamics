# %% [markdown]
# <h2 align="center"> Estudo da termodinâmica de uma usina elétrica a vapor </h3>
#
# <h4 align="center"> Ilum - Escola de Ciência | Curso: Termodinâmica Avançada (2023) | Ministrada pelo Profº Amauri Jardim de Paula </h3>
#
# <h3 align="justify">  Descrição do Problema <h3>
# <p align="justify"> Foi proposto, dentro da disciplina de Termodinâmica Avaçanda, da Ilum - School of Science, o estudo do funcionamento de uma usina termoelétrica, além da simulação e analise de cada fase da produção de energia através de tranformações térmicas e físico-químicas de uma mistura líquida de dois diferentes compostos, afim de compreender os fundametos teóricos por trás destes fenômenos. </p>
#
# <p align="justify"> O projeto será desenvolvido em seis etapas com objetivos específicos a serem concluídos. Essas etapas serão tratadas como Desafios, de acordo com o roteiro proposto. A cada Desafio, serão explorados temas como energia, entalpia, transição de fases, misturas e soluções e ciclos termodinâmicos. Ao final do projeto, espera-se obter todos os parâmetros necessários para o fucionamento de um sistema termoelétrico com base na mistura de líquidos escolhida. </p>
#
# <p align="center"><img src="https://user-images.githubusercontent.com/106619091/225313553-b47b8234-48aa-4ef2-aeb5-2177a5c42312.png"></p>
#
# <h5 align="justify" style= "color: red;"> Observação: A descrição do problema foi bem abordada, assim como a idealização do projeto. A imagem acima possibilitou uma melhor visualização das etapas. </h5>
#
# <h2 align="center"> <img src="https://user-images.githubusercontent.com/106678040/226234219-007276df-12e9-46ee-af02-68471b39f593.png"/> </h2>
#
#
# <hr>

# %% [markdown]
# <h3 align="justify">  Descrição da Atividade <h3>
#
# <p align="justify">  As usinas termoelétricas são instalações industriais utilizadas para a geração de energia elétrica, por meio de um processo que libera energia pela queima de algum tipo de combustível, seja este, renovavél ou não. No Brasil, a usina termoelétrica é utilizada desde o final do século XIX, e hoje seu uso é feito de modo estratégico, para suprir as demandas de energia nos períodos de seca. </p>
#
# <p align="justify"> Dada a relevância deste método de geração de energia e a vasta gama de conceitos da termodinâmica envoltos no processo desta, a disciplina tem como objetivo o estabelecimento dos parâmetros relevantes envolvidos no funcionamento de um sistema composto por uma usina elétrica a vapor operando a partir da combustão de uma mistura líquida de combustíveis. Logo, as discentes irão desenvolver um projeto de estudo do funcionamento de uma usina termoelétrica que é divido em seis etapadas nomeadas de Desafio. </p>
# <p align="justify"> No presente arquivo, introduz-se as misturas líquidas que irão gerar combustão afim de se resolver a primeira etapa de estudo (Desafio 1). </p>
#
#
# **Desafio 1 - Definir a mistura combustível**
# <p align="justify"> A mistura de líquidos combustíveis a ser usada deverá ser determinada a partir das seguintes propriedades e considerações:
#
# *  Entalpia de combustão;
# *  Existência de um diagrama de fases já determinado para a mistura. </p>
#
# **Instruções**
#
# <p align="justify">  O primeiro desafio para solução do problema principal da disciplina envolve:
#
# *  A definição de uma mistura com potencial para fornecimento de energia ao ciclo Rankine (responsável pela geração de energia elétrica) 	&rarr;  Nessa parte os grupos deverão definir os critérios os quais servirão para escolher a mistura. Uma propriedade importante a ser considerada é a entalpia, que é definida como uma função potencial termodinâmica. </p>
#
# <p align="justify">  Para tal, alguns aspectos termodinâmicos importantes devem ser considerados. </p>
#
# * Outro  aspecto importante a ser considerado é que a mistura deverá ser estudada em seu estado líquido em algum momento ao longo do desenvolvimento do problema. Para isso, os grupos deverão considerar os Diagramas de Fase dos compostos e da mistura.
#
# <p align="justify"> Ok! Dado os objetivos e instruções do Desafio 1, discorre-se no presente arquivo, os líquidos combustíveis de escolha determinados pelas desenvolvedoras do projeto! </p>
#
# <h5 align="justify", style= "color: red;"> Observação: A descrição da atividade já havia sido passada para todos os alunos, então a sua citação no notebook foi um pouco redundante. Seria adequado caso a atividade fosse mostrada/disponibilizada para o público externo à Ilum. </h5>

# %% [markdown]
# <h2 align="center"> <b> PLANO DE PROJETO: TERMOELÉTRICA MOANA S.A. </b>  </h3>
#
# <p align="justify">
# Termoelétricas produzem energia a partir do ciclo de potência a vapor, sendo o vapor gerado pela queima de combustíveis que fazem girar turbinas convertendo este trabalho em energia. O processo que faz essa produção de energia é denominado de Ciclo Rankine que aproveita o vapor que sai das turbinas condensando-o e transformando-o em líquido para realizar o ciclo repetidamente.</p>
# <p align="justify">
# Em síntese, ele possibilita por meio de ciclos termodinâmicos que o trabalho mecânico seja extraído de um fluido à medida que ele se move entre uma fonte de calor e um dissipador de calor. A fim de se ter essa energia é necessário ter uma boa queima de combustíveis com o intuito de promover uma grande quantidade de calor e energia, desse modo, o questionamento que se perpetua é:</p>
# <p align="center">
# "Como determinar bons combustíveis para a geraçãer de energia?"
#
# De modo a determinar bons combustíveis que gerem energia, um dos conceitos bases para esta definição é a entalpia e o diagrama de fases dos compos
# os.</p>
#
# <h5 align="justify" style="color: red;"> Observação: Ótima explicação do Ciclo de Rankine </h5>
#
# <h4 p align="justify"> <b> Entalpia </b> </p> </h4>
# <p align="justify">  Entalpia pode ser compreendida como a quantidade de calor (energia) recebida ou absorvida no sistema por conta de uma mudança no próprio sistema ou pela quantidade de calor expelido pelo sistema como resultado da alteração deste. É um conceito muito utilizado em medições em sistemas biológicos, químicos e físicos a uma pressão constante fornecida pela atmosfera ambiente. </p>
#
# <p align="justify">  . De acordo com o  Schroeder et. al Addison Wesley Longman(1999), a ideia de processos de pressão constante é muito utilizada no dia a dia comercial e laboratorial em estudos de compressão-expansão e devido esta utilização constante, ao longo dos anos aprende-se algumas abordagens mais convenientes para a determinação destes, isto é,  podemos ao invés de pensar na energia do sistema, refletir a respeito do trabalho necessário para a geração do sistema que é expresso pelo produto da pressão pelo espaço (P x V) e quando adicionamos energia a este produto, obtemos a Entalpia, denotada por H: </p>
#
# <p align="center"><img src="https://user-images.githubusercontent.com/106678040/226898642-1ad9644b-136b-4297-8ad1-3540bc9d480d.png"></p>
# Fonte: David Schroeder (1999).
# <p align="justify">
# Essa mensuração é a H total do sistema que você precisaria obter para criar o sistema do nada e colocá-lo nesse ambiente. </p>
#
# <p align="justify">A fim de entender a utilidade da Entalpia, pense em situações que ocorram uma mudança no sistema - reação de produtos químicos ou surgimento de calor -  enquanto a pressão é sempre mantida de modo constante. Por meio do cálculo de entalpia, conseguimos determinar a energia liberada em forma de calor por meio da movimentação das moléculas de uma reação quimíca transformada pelo produto desta.
#   </p>
# <p align="justify">
# Existem alguns tipos de entalpia a serem utilizados, no presente momento, iremos dissertar a respeito de um tipo muito importante para a geração de calor: a entalpia de combustão.  </p>
# <br>
#
# <h4 p align="justify"> <b> Entalpia  de Combustão </b> </p> </h4>
#
# <p align="justify">
# Entalpia de combustão pode ser compreendida como uma energia liberada no modo de calor por meio de uma combustão de 1 mol de substância. Esta entalpia pode  se usada para comparar quais combustíveis ou substâncias liberam mais energia quando são queimados. </p>
#
# <h5 align="justify", style= "color: red;"> Observação: Nota-se que os autores compreenderam os conceitos necessários para a realização da atividade, visto a ótima explicação do conceito de entalpia e entalpia de combustão. </h5>
#
# <p align="justify">
# Dada esta categorização e pensando no ciclo de Rankine, o método para a definição dos combustíveis para a mistura é baseada em uma proposta principal: compositos com alta entalpia de combustão. Desse modo, seleciona-se como mistura: Methanol e Ethyl Acetato. </p>
# <br>
#
# <h5 align="justify", style= "color: red;"> Observação: Entendemos que a escolha dos dois compostos foi baseada na alta entalpia de combustão, visando o uso do Ciclo Rankine, porém visto que existem outros compostos que apresentam entalpias de combustão ainda maiores, o que teria motivado a escolha destes dois? Não nos ficou muito claro. </h5>
#
# <h4 p align="justify"> <b> Mistura: Methanol + Ethyl Acetate </b> </p> </h4>
# <p align="justify">
# O Methanol(CH4O) é um alcoól volátil utilizado para inúmeros produtos do dia a dia, desde plástico até materiais de construção. Atualmente, ele também é utilizado como um recurso de energia limpa, sendo utilizado como um combustível para abastecer carros, navios, caldeiras e até fogões. </p>
#
# <p align="justify"> Por sua vez, o Ethyl Acetate é um composto orgânico muito utilizado na indústria de solvente como solvente ou diluente e é formado pela composição entre o ácido acético e o etanol. Ademais, ele também é utilizado como combustíveis e na produção de plásticos. </p>
#
# <p align="justify"> Dada a breve descrição dos compostos, vimos que esta mistura é composta por dois compostos utilizados como combustíveis o que contribui para a formação de combustão destes e consequentemente, a liberação de energia. Ademais, a entalpia destes apresenta um valor médio-alto de excecução, sendo estes Methanol (-715 kJ/mol) e Ethyl acetate(-478 kJ/mol) - os valores são negativos visto que representam a liberação da energia.</p>
#
# <p align="justify"> Na Tabela 1, observa-se uma categorização básica dos componentes a serem utilizados.</p>
#
# <br>
#
# <th> <table border="1">
#     <tr>
#         <td>Fórmula </td>
#         <td>Massa Molar</td>
#         <td>Nome do composto</td>
#         <td>Entalpia de combustão</td>
#     </tr>
#     <tr>
#         <td>CH4O</td>
#         <td>32.042</td>
#         <td>Methanol</td>
#         <td>−715,0 kJ/mol</td>
#     </tr>
#     <tr>
#         <td>Ralf</td>
#         <td>C4H8O2</td>
#         <td>Ethyl acetate</td>
#         <td>-478,82 kJ/mol</td>
#     </tr>
# </table>
# </th>
# <br>
#
# <h5 align="justify", style= "color: red;"> Observação: Muito importante mostrar a fórmula química e as entalpias de combustão relacionadas em tabela, facilitando a visualização. Um detalhe que faltou, seria de onde foi obtida a entalpia de combustão do acetato de etila, visto que nas referências é encontrado a entalpia de combustão apenas do etanol. </h5>
#
# <h4 p align="justify"> <b> Diagrama de Fases </b> </p> </h4>
#
# <p align="justify"> O diagrama de fases binários descreve a relação das fases dos compostos, nele é possível identificar o estado liquído e gasoso deste, além do meio das linhas representar o ponto da mistura dos compositos. É bom se ter um diagrama bem definido para sabermos as considições ideias para a separação da mistura e utilização destas para o processo de liberação de energia. Na Figura 2, observa-se o diagrama de fases da mistura do Methabol + Ethyl Acetate que apresenta linhas bem definidas deste.  </p>
# <p align="justify"> Neste gráfico, a pressão é de 101.325 kPa. </p>
#
# <p align="center"><img src="https://user-images.githubusercontent.com/106678040/226884392-431d38c9-4f96-4f79-ac7a-8ee173c47f42.png"></p>
# Figura 2. Diagrama de Fases do Methabol + Ethyl Acetate(DDBST GMBH).
#
# <br>
#
# <h5 align="justify", style= "color: red;"> Observação: Nota-se que os autores também compreenderam a função do diagrama de fases e a relação dos compostos presentes. A imagem está em ótima resolução e o diagrama está, corretamente, em função da Temperatura, visto que a Pressão será mantida constante durante a atividade </h5>
#
# <h4 p align="justify"> <b> Referências Bibliográficas </b> </p> </h4>
#
# - WIKIPEDIA CONTRIBUTORS. Methanol (data page). Disponível em: <https://en.wikipedia.org/wiki/Methanol_(data_page)>. Acesso em: 22 mar. 2023.
#
# - DDBST GMBH. Vapor-Liquid Equilibrium Data of Ethyl acetate + Methanol from Dortmund Data Bank. Disponível em: <http://unifac.ddbst.de/en/EED/VLE/VLE%20Ethyl%20acetate%3BMethanol.php>. Acesso em: 22 mar. 2023.
# - GRANDE, J. C. Physical Chemistry a molecular approach; McQuarrie Donald A., Simon John A.; University Science Books; 1997; California. Disponível em: <https://www.academia.edu/44472489/Physical_Chemistry_a_molecular_approach_McQuarrie_Donald_A_Simon_John_A_University_Science_Books_1997_California>. Acesso em: 22 mar. 2023.
# - Enthalpy of combustion - Chemical energy - Higher Chemistry Revision - BBC Bitesize. Disponível em: <https://www.bbc.co.uk/bitesize/guides/z8p72hv/revision/3>. Acesso em: 22 mar. 2023.
# - MLA. Schroeder, Daniel V. An Introduction to Thermal Physics. San Francisco, CA :Addison Wesley, 1999. APA. Schroeder, Daniel V. (1999).

# %% [markdown]
# ### Observações Gerais
#
# **- No geral, os autores apresentam ótima compreensão do conteúdo geral envolvendo entalpia de reações químicas, e como estas podem afetar a geração de energia para o Ciclo Rankine. As discussões sobre as escolhas dos compostos, suas funções individuais e suas propriedades termodinâmicas foram bem elaboradas e justificadas. Achamos muito legal utilizar HTML para formatação do notebook, deixando-o como um todo muito bem organizada, bem separado, e de fácil compreensão**
#
# ### Critério de Avaliação
#
# **- Para a avaliação da atividade, levamos em consideração a compreensão dos conceitos termodinâmicos abordados durante as aulas e disponíveis nos materiais para leitura, como a definição teórica e matemática de Entalpia e Entalpia de combustão, os critérios de escolha dos reagentes e como estes podem prover energia ao Ciclo Rankine, bem como a explicação do funcionamento deste último, a disponibilização do diagrama de fases da mistura binária e sua interpretação. Também foi avaliado a organização do notebook e a utilização de informações adicionais que poderiam facilitar o entendimento de um conceito.**
